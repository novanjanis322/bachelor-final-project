# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import os

# %%
dir = './drive/MyDrive/TA Tugas Akhir Workspace/Dataset/Train'

# %%
df = pd.read_csv(dir + '/ytprambanan2.csv')
df.head()
# Out:
#                            id  \
# 0  Ugx4A1ciR6-q1iuLeO54AaABAg
# 1  Ugwqun0bs8T0MqoLhuJ4AaABAg
# 2  UgzLgKrY_V4hfe4Pmu94AaABAg
# 3  UgzXpEE9a0GAciJ0apd4AaABAg
# 4  Ugz7Gx5UYWtrwYHvfJF4AaABAg
#
#                                         textOriginal  \
# 0  Inilah bukti nyata sejarah leluhur hindu NUSAN...
# 1  CANDI PRAMBANAN,  maha karya agung 👍, luar bia...
# 2  Candi Prambanan sangat indah bagaikan Surga. B...
# 3  Tahun 2015 bersyukur sudah pernah menginjakkan...
# 4  Saya sebagai umat Hindu sangat bangga dan sang...
#
#             authorChannelId      authorDisplayName  likeCount  \
# 0  UCqA9A_Zc_-EG3dxNkP-uVaA  @igustisuartajaya8046         52
# 1  UCp3oe8snkBG-YSbsY_T5Rqw      @iwayansumerta253         21
# 2  UCoAeSX0av0Jh0kUFvADrLwA       @gedesaryata7186         17
# 3  UCCfCkq9CZpqlfbVvz1qdfug         @mamakdayak925         15
# 4  UCLOhSHeuWo0JH7N7QBIL5LA  @putuwiramahasandi428         15
#
#             publishedAt
# 0  2022-04-10T10:58:22Z
# 1  2022-06-25T23:03:51Z
# ...

# %%
df = pd.read_csv(dir + '/Tiktok_prambanan1.csv')
df.head()
# Out:
#             Comment_ID            Author_ID      Author  \
# 0  7352807393921221381  7276327262969463814      cer.64
# 1  7354101741417726725  6571264495653044226      r4a___
# 2  7354175450358399750  6878220614285853701  ucimeylani
# 3  7354041271454040837  6974274678932358146   xly.zaraa
# 4  7352670272598147845  6953214550665741313     ghs.yaa
#
#                                                 Text  Likes  \
# 0                                keluar nya jauh bgt   5893
# 1  seribu kenangan, walaupun cape jalan keluar ny...   5468
# 2  candi prambanan aku titip kenanganku ditempatm...   3502
# 3        kangen bgt sama jogja, apalgi kenangan nya.   2675
# 4                               aku, kamu, Prambanan    750
#
#           Comment_Date
# 0  2024-04-01 15:08:17
# 1  2024-04-05 02:50:54
# 2  2024-04-05 07:36:54
# 3  2024-04-04 22:56:18
# 4  2024-04-01 06:16:07

# %%
sentiment_df = pd.read_excel('./drive/MyDrive/TA Tugas Akhir Workspace/Dataset/Train/labelled_data.xlsx')
sentiment_df.head(3)
# Out:
#                                                 text sentiment
# 0                                keluar nya jauh bgt  negative
# 1  seribu kenangan, walaupun cape jalan keluar ny...  negative
# 2  candi prambanan aku titip kenanganku ditempatm...   neutral

# %%
sentiment_map = dict(zip(sentiment_df['text'], sentiment_df['sentiment']))

# %%
directory = './drive/MyDrive/TA Tugas Akhir Workspace/Dataset/Train'
csv_files = [os.path.join(directory, f) for f in os.listdir(directory) if f.endswith('.csv')]
csv_files
# Out:
# ['./drive/MyDrive/TA Tugas Akhir Workspace/Dataset/Train/Tiktok_prambanan1.csv',
#  './drive/MyDrive/TA Tugas Akhir Workspace/Dataset/Train/ytmalioboro3.csv',
#  './drive/MyDrive/TA Tugas Akhir Workspace/Dataset/Train/ytprambanan2.csv',
#  './drive/MyDrive/TA Tugas Akhir Workspace/Dataset/Train/ytmalioboro.csv',
#  './drive/MyDrive/TA Tugas Akhir Workspace/Dataset/Train/ytmalioboro2.csv']

# %%
for file in csv_files:
    df = pd.read_csv(file)
    if 'Text' in df.columns:
      df['sentiment'] = df['Text'].map(sentiment_map)
    elif 'textOriginal' in df.columns:
      df['sentiment'] = df['textOriginal'].map(sentiment_map)
    # Save the updated DataFrame to a new CSV file
    output_file = os.path.join(directory, 'updated_' + os.path.basename(file))
    df.to_csv(output_file, index=False)
